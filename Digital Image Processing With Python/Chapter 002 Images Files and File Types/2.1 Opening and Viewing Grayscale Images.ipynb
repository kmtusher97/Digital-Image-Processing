# %%
import skimage.io as io

# %% [markdown]
# Read an image

# %%
img = io.imread('_images/hiramon.png')

# %% [markdown]
# Show the image

# %%
io.imshow(img)

# %%
io.imshow('_images/hiramon.png')
