# %%
import skimage.io as io

# %%
im = io.imread('_images/caribou.jpg')
io.imshow(im)

# %%
io.imshow(im + 128)

# %%
io.imshow(im - 228)

# %%
import numpy as np

io.imshow(np.uint8((im + 80) % 256))

# %%
io.imshow(im * 5)

# %%
io.imshow(im // 4) ## // for integer division

# %% [markdown]
# ## Complemnt Image

# %%
io.imshow(255 - im)
